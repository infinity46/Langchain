# %%
## Open source models -- LLama3, Gemma2, mistral -- groq
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model=ChatGroq(model="Gemma2-9b-It",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(output_version=None, profile={}, client=<groq.resources.chat.completions.Completions object at 0x000001CD05585840>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001CD05585AB0>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)
